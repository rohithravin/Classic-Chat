# %%
# import required libraries
import getpass
import requests
import ssl
import json
import pandas
from tabulate import tabulate
from requests import Response
from requests.packages.urllib3.exceptions import InsecureRequestWarning
requests.packages.urllib3.disable_warnings(InsecureRequestWarning)

# %%
# REST server information
restURL = "https://sparge1.fyre.ibm.com:50050"

# Db2 database information
hostName = "acbuild1.fyre.ibm.com"
port = 50001
databaseName = "BLUDB"
databaseUName = "bluadmin"
databasePassword = "password"

# Token used to authenticate REST calls
token = ""

# %%
# Aquire Token
credentials = {
    "dbParms": {
        "dbHost": hostName, 
        "dbPort": int(port), 
        "dbName": databaseName, 
        "username": databaseUName, 
        "password": databasePassword },
    "expiryTime": "72h"
}

r = requests.post(restURL + "/v1/auth", verify = False, json = credentials, proxies = None)
    
if (r.status_code == 200):
    token = r.json()["token"]
    print("Connected.")
    print("Token:", token)
else:
    print(r.status_code, r.reason)
# Out:
# Connected.
# Token: eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhZG1pbiI6dHJ1ZSwiY2xpZW50X2lkIjoiNjA2NDQxMGUtZTc3Zi00OTRiLTk0MjItYzU3YTIwNjczN2E5IiwiZXhwIjoxNTc2MjA2ODE0LCJpc3MiOiJibHVhZG1pbiJ9.qrVDSn2hXg7prqQwISoowmAYcusWliluLrPaV2BG7Mw

# %%
# Create 'User' Table

headers = {
  "authorization": token,
  "content-type": "application/json"
}

body = {
  "sqlStatement": 'CREATE TABLE "BLUADMIN"."CLASSIC_CHAT_USERS"  ( \
    "USER_ID" INTEGER NOT NULL GENERATED BY DEFAULT AS IDENTITY ( \
            START WITH +1 \
            INCREMENT BY +1 \
            MINVALUE +1 \
            MAXVALUE +2147483647 \
            NO CYCLE \
            CACHE 20 \
            NO ORDER ), \
    "FIRST_NAME" VARCHAR(100) NOT NULL, \
    "LAST_NAME" VARCHAR(100) NOT NULL, \
    "EMAIL" VARCHAR(100) NOT NULL, \
    "PASSWORD" VARCHAR(100) NOT NULL, \
    "DATE_CREATED"  NOT NULL DEFAULT CURRENT_TIMESTAMP ) '
}

response = requests.post(restURL + "/v1/services/execsql", 
                         headers=headers, 
                         json=body, 
                         proxies = None, 
                         verify = False)

if (response.status_code == 200):
    id = response.json()["id"]
    print(id)
else:
    print(response.json())
# Out:
# {'id': 'db90cfa8-b7aa-43c6-bdba-3a51f5e96c1d'}

# %%
# Create 'User' Table

headers = {
  "authorization": token,
  "content-type": "application/json"
}

body = {
  "sync":"true",
  "sqlStatement": 'SELECT * FROM "BLUADMIN"."CLASSIC_CHAT_USERS"'
}

response = requests.post(restURL + "/v1/services/execsql", 
                         headers=headers, 
                         json=body, 
                         proxies = None, 
                         verify = False)

if (response.status_code == 200):
    print(response.json())
else:
    print(response.json())
# Out:
# {'id': 'b9ed3448-2f4f-4284-8c98-8fa24ee2aaa1'}
